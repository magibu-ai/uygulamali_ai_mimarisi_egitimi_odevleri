# %% [markdown]
# <a href="https://colab.research.google.com/github/Aysenuryesilova/namaz-vakti-magibu-proje/blob/main/src/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🕌 Namaz Vakti ve Fıkıh Asistanı (Google Colab Canlı Demo)
# ### Custom Jinja2 Chat Template & Tool-Calling AI Assistant
# Bu notebook, projeyi Google Colab üzerinde ücretsiz çalıştırarak **canlı ve herkese açık bir Gradio linki** (`https://xxxx.gradio.live`) üretir.

# %%
# 1. GitHub Reposunu Klonlama ve Dizin Ayarları
# !git clone https://github.com/Aysenuryesilova/namaz-vakti-magibu-proje.git
# %cd namaz-vakti-magibu-proje

# %%
# 2. Gerekli Kütüphaneleri Yükleme
# !pip install -q -r src/requirements.txt

# %%
# 3. Canlı Gradio Paylaşım Linkini (share=True) Başlatma
import sys
import os
sys.path.append("src")

from app import demo

# share=True sayesinde herkese açık https://xxxx.gradio.live bağlantısı üretilir
demo.launch(share=True, debug=True)
